# %% [markdown]
# # **Point 4.**
# The choosen players Khalid Eissa and Ismaël Aaneba have different variables of the highest importance. The most important feature for Khalid Eissa is his Dribbling Total while for Ismaël Aaneba it is Release Clause.

# %% [markdown]
# # **Point 5.**
#
# I have guessed that it could be the age of a player which may contribute both negatively or positively to some predictions. Even if some player has several promising skills, this promise will not be fulfilled when he is rather old. On the other hand, young players can develop their talents even if they are not so brilliant at the moment.
#
# The biggest shap value for age is: 507480.0 and the smallest is: -179119.015625.
# The ages of the players are 24 and is 33. Their names are: Heung Min Son (young) and Antonio Rüdiger (old).

# %% [markdown]
# The graph below shows the importance of observations calculated with dalex package.

# %%
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 3708 rows 84 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 3708 values
#   -> model_class       : xgboost.sklearn.XGBRegressor (default)
#   -> label             : Not specified, model's class short name will be used. (default)
#   -> predict function  : <function yhat_default at 0x7f22bf7d10e0> will be used (default)
#   -> predict function  : Accepts only pandas.DataFrame, numpy.ndarray causes problems.
#   -> predicted values  : min = 3.74e+05, mean = 1.87e+06, max = 6.13e+07
#   -> model type        : regression will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -5.93e+06, mean = 1.05e+06, max = 5.41e+07
#   -> model_info        : package xgboost
#
# A new explainer has been created!
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %% [markdown]
# # **Point 6.**
# First and foremost, they differ by the fact shap library returns both positive and negative values while dalex returns only positive.

# %% [markdown]
# # **Point 7.**
#
#
# Observation for which SHAP attributions differ the most is 'LB Rating'. 'LB' stands for 'Linebracker', in Polish: 'Wspomagający', which is a position in Amercian football, not in soccer. This observation seems to be irrelevant for values prediction task since it concerns another discipline. On the other hand, it might be useful as an indicator of physical strentgh, which is necessary for some soccer players and might significantly influence the model prediction. One possible explanation of different SHAP values for two models is that one of them could be somehow able to calculate these observation based on others so that this observation turns out to be unimportant. The other possible explanation is that the model has great amount of observations which might perhaps lead to neglect some of them in the case of XGBoost.

# %% [markdown]
# # **Point 8.**
#
# I trained two models: XGBoost and linear regression on FIFA 23 dataset with a goal of predicting value of football players based on numerous observations. Calculation of the decomposition of predictions showed that for different players some other observations turn out to be more important. Namely, I indicated two players such that for one of them the biggest positive influence on the predicted value was exerted by Dribbling Total which was negative for the other player.
#
# Two packages give different values, values calculated by shap are of both signs while values obtained by dalex may be only positive.
#
# For the linear model trained in point 7. it came out that SHAP attributions for this model are different than those obtained from XGBoost model. I proposed two possible explanation of such a phenomenon. For the observation 'LB Rating' which has big impact on prediction for linear model and rather small for XGBoost. At first glance it might be the case that XGBoost copes with calculating somehow this observation based on the others and thus this very feature does not influence the prediction. The second explanation can be that due to the great amount of the data some of them are neglected simply by the reasons of statistics; it cannot be the case that all the features are very important for the prediction.
