# %% [markdown]
# # Task 1

# %% [markdown]
# $f(x_1, x_2) = (x_1+x_2)^2$, where $x_1, x_2 \sim U[-1, 1]$ <br><br>
# **PD** <br>
# $g_{PD}^1(z) = \mathbb{E}_{x_2} (z + x_2)^2 = z^2 + 2z\mathbb{E}_{x_2}x_2 + \mathbb{E}_{x_2} x_2^2 = z^2 + 0 + \int_{-1}^1 \frac{1}{2} v^2 dv = z^2 + 1/3$ <br><br>
# **ME** <br>
# $g_{ME}^1(z) = \mathbb{E}_{x_2 | x_1=z} (z + x_2)^2 = \mathbb{E}_{x_2 | x_1=z} 4z^2 = 4z^2$ <br><br>
# **ALE** <br>
# $g_{AL}^1(z) = \int_{-1}^z \mathbb{E}_{x_2 | x_1=v} \frac{∂(x_1+x_2)^2}{∂x_1}dv = \int_{-1}^z \mathbb{E}_{x_2 | x_1=v} (2x_1 + 2x_2)dv = \int_{-1}^z \mathbb{E}_{x_2 | x_1=v} 4v dv = 2z^2 - 2$

# %% [markdown]
# # Task 2

# %% [markdown]
# # Raport

# %% [markdown]
# I'm working on the Heart Attack dataset.
# Short description of variables:
# * `age`: The person's age in years
# * `sex`: The person's sex
#   * 1: male
#   * 0: female
# * `cp`: chest pain type
#   * 0: asymptomatic
#   * 1: atypical angina
#   * 2: non-anginal pain
#   * 3: typical angina
# * `trtbps`: The person's resting blood pressure (mm Hg on admission to the hospital)
# * `chol`: The person's cholesterol measurement in mg/dl
# * `fbs`: The person's fasting blood sugar (> 120 mg/dl)
#   * 1: true
#   * 0: false
# * `restecg`: Resting electrocardiographic measurement
#   * 0: showing probable or definite left ventricular hypertrophy by Estes' criteria
#   * 1: normal
#   * 2: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# * `thalachh`: The person's maximum heart rate achieved
# * `exng`: Exercise induced angina
#   * 1: true
#   * 0: false
# * `oldpeak`: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot.)
# * `slp`: the slope of the peak exercise ST segment
#   * 0: downsloping
#   * 1: flat
#   * 2: upsloping
# * `caa`: The number of major vessels (0-3) colored by fluoroscopy
# * `thall`: Results of the blood flow observed via the radioactive dye
#   * 0: NULL (dropped from the dataset previously)
#   * 1: fixed defect (no blood flow in some part of the heart)
#   * 2: normal blood flow
#   * 3: reversible defect (a blood flow is observed but it is not normal)
# * `output`: Heart disease (target)
#   * 0: disease
#   * 1: no disease

# %% [markdown]
# ## 2.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1r0_NnA4PI8fRNQ88ISd38tJyNMQPuOR1)
# ![](https://drive.google.com/uc?export=view&id=1iErK2_DsYNi7QvndnDbE1XHPTabJNUiJ)
# ![](https://drive.google.com/uc?export=view&id=1y3Gpvnp5T8ksfja5BT6E97N4cGpLHCre)
# ![](https://drive.google.com/uc?export=view&id=16kRTAUSSgsFs7w-VBFJ-o3jnVtpzid7x)

# %% [markdown]
# From the plots above one can see that the CP Profiles with respect to the `age` variable depend on the sample. For instance, for observation `150` manipulating `age` can cause changing of prediction, which is close to 0.5. For the other samples changing only the `age` variable doesn't influence model's (binary) prediction.

# %% [markdown]
# ## 3.
# We can also visualize CP Profile for many variables at the same time. Below we can find this type of plot for 4 samples from the previous point.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1llWGoVyJuYRzTw5DW_nmSP5oQigz_LOh)

# %% [markdown]
# For example, the observation `0` (second from the top) is mostly decreasing, whereas the observation `225` (the bottom one) is increasing. Tree-based methods are generally able to express interactions. Here we can see the example of this - estimation of a prediction of a sample can either fall or rise with the `age` variable, which implies that this variable interacts with others.

# %% [markdown]
# ## 4.

# %% [markdown]
# The PDP plot can be quite confusing, as for younger patients the prediction is greater (1 - no disease) and for patients in their 60s the prediction falls, which is consistent with intuition. However, for even older patients prediction increases again, which can be counterintuitive. Despite that, it is fairly consistent with what we've seen on CP plots. There are few possible explanations of this issue. Maybe it's caused by correlation between features, for instance, older patients are more likely to make check-ups, so they can detect alarming symptoms sooner and can prevent the disease.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1TyoTg3pwKGYFs2GyzuU2SKeWQ6vhv52C)

# %% [markdown]
# ## 5.
# Interestingly, the PDP Profile is much smoother in case of Random Forest (below). Nevertheless, both plots follow similar trend - from high values to lower and then greater again. However, here this (rather) unlikely phenomena spotted in the previous point is much less significant.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1H_A7Vn5XplSbkSdRK5ctHS0Guitm75kb)

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Import packages

# %%
# !pip install dalex &>/dev/null
# !pip install lime &>/dev/null

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix,\
  ConfusionMatrixDisplay, f1_score, recall_score, precision_score
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
import dalex as dx
import lime

SEED = 42

# %% [markdown]
# ## Load data

# %%
# !gdown 14RnHkHVRmZHdXF7_THt7arQzlzplKbF1
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14RnHkHVRmZHdXF7_THt7arQzlzplKbF1
# To: /content/heart.csv
# 100% 11.3k/11.3k [00:00<00:00, 14.7MB/s]

# %%
df_raw = pd.read_csv('heart.csv')
df_raw.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# ## Data preprocessing

# %%
df_raw.info() # only int and float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
print(df_raw.shape) # 303 observations, 14 variables (including one output class)
df_raw.describe()
# Out:
# (303, 14)
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# Based on the data and documentation from kaggle we should apply one-hot encoding transformation to the following variables: `cp`, `restecg`, `slp` and `thall`.

# %%
df = pd.get_dummies(df_raw, columns=['cp', 'restecg', 'slp', 'thall'])
df.head()
# Out:
#    age  sex  trtbps  chol  fbs  thalachh  exng  oldpeak  caa  output  ...  \
# 0   63    1     145   233    1       150     0      2.3    0       1  ...
# 1   37    1     130   250    0       187     0      3.5    0       1  ...
# 2   41    0     130   204    0       172     0      1.4    0       1  ...
# 3   56    1     120   236    0       178     0      0.8    0       1  ...
# 4   57    0     120   354    0       163     1      0.6    0       1  ...
#
#    restecg_0  restecg_1  restecg_2  slp_0  slp_1  slp_2  thall_0  thall_1  \
# 0          1          0          0      1      0      0        0        1
# 1          0          1          0      1      0      0        0        0
# 2          1          0          0      0      0      1        0        0
# 3          0          1          0      0      0      1        0        0
# 4          0          1          0      0      0      1        0        0
#
#    thall_2  thall_3
# 0        0        0
# 1        1        0
# 2        1        0
# 3        1        0
# 4        1        0
#
# [5 rows x 24 columns]

# %%
X = df.drop('output', axis=1)
y = df.output

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED, stratify=y)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# With stratify argument we can assure than the proportion of values in the sample produced will be the same as the proportion of values in `y`.
#
# Also, I decided to standardize features by removing the mean and scaling to unit variance. We don't want a feature that has a variance that is orders of magnitude larger than others.
#
# For now I will use just train/test split, in the future I can extend it with train/val/test split if needed.

# %% [markdown]
# ## Train a XGBoost model

# %%
BST_model = xgb.XGBClassifier(random_state=SEED, max_depth=2).fit(X, y)

# %% [markdown]
# ## Evaluate model on some examples

# %%
pf_xgboost_classifier_default = lambda m, d: m.predict_proba(d)[:, 1]
explainer = dx.Explainer(BST_model, X, y, predict_function=pf_xgboost_classifier_default, label="GBM")
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 303 rows 23 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 303 values
#   -> model_class       : xgboost.sklearn.XGBClassifier (default)
#   -> label             : GBM
#   -> predict function  : <function <lambda> at 0x7f95549dadd0> will be used
#   -> predict function  : Accepts only pandas.DataFrame, numpy.ndarray causes problems.
#   -> predicted values  : min = 0.00365, mean = 0.544, max = 0.995
#   -> model type        : classification will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -0.929, mean = 0.000168, max = 0.836
#   -> model_info        : package xgboost
#
# A new explainer has been created!

# %% [markdown]
# Check performance

# %%
explainer.model_performance()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f1</th>
#       <th>accuracy</th>
#       <th>auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>GBM</th>
#       <td>0.933333</td>
#       <td>0.905882</td>
#       <td>0.919403</td>
#       <td>0.910891</td>
#       <td>0.978788</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
observations = X.iloc[:300:75] # choosing 4 observations
observations
# Out:
#      age  sex  trtbps  chol  fbs  thalachh  exng  oldpeak  caa  cp_0  ...  \
# 0     63    1     145   233    1       150     0      2.3    0     0  ...
# 75    55    0     135   250    0       161     0      1.4    0     0  ...
# 150   66    1     160   228    0       138     0      2.3    0     1  ...
# 225   70    1     145   174    0       125     1      2.6    0     1  ...
#
#      restecg_0  restecg_1  restecg_2  slp_0  slp_1  slp_2  thall_0  thall_1  \
# 0            1          0          0      1      0      0        0        1
# 75           1          0          0      0      1      0        0        0
# 150          1          0          0      0      0      1        0        1
# 225          0          1          0      1      0      0        0        0
#
#      thall_2  thall_3
# 0          0        0
# 75         1        0
# 150        0        0
# 225        0        1
#
# [4 rows x 23 columns]

# %%
explainer.predict(observations)
# Out:
# array([0.6567136 , 0.94133586, 0.4969589 , 0.09892399], dtype=float32)

# %%
observations.index[1]
# Out:
# 75

# %% [markdown]
# ## Calculate what-if explanations of some predictions

# %%
for i in range(len(observations)):
    cp = explainer.predict_profile(observations.iloc[i])
    cp.plot(variables=['age'], title=f'Ceteris Paribus Profiles for obs {observations.index[i]}')
# Out:
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:00<00:00, 217.20it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e5c98314-1f28-4b3c-8e73-21230f783753" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5c98314-1f28-4b3c-8e73-21230f783753")) {                    Plotly.newPlot(                        "e5c98314-1f28-4b3c-8e73-21230f783753",                        [{"customdata":[["</br>id: 0</br>prediction: 0.81</br>age: 29.0</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 29.48</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 29.96</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 30.44</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 30.92</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 31.4</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 31.88</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 32.36</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0 ...
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:00<00:00, 131.10it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e574d00a-c53e-47d0-9a2f-3ba07290d978" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e574d00a-c53e-47d0-9a2f-3ba07290d978")) {                    Plotly.newPlot(                        "e574d00a-c53e-47d0-9a2f-3ba07290d978",                        [{"customdata":[["</br>id: 75</br>prediction: 0.97</br>age: 29.0</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 29.48</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 29.96</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 30.44</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 30.92</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 31.4</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 31.88</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 1.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 1.0</br>thall_3: 0.0</br>_original_yhat_: 0.9413358569145203</br>"],["</br>id: 75</br>prediction: 0.97</br>age: 32.36</br></br>sex: 0.0</br>trtbps: 135.0</br>chol: 250.0</br>fbs: 0.0</br>thalachh: 161.0</br>exng: 0.0</br>oldpeak: 1.4</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 1.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br ...
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:00<00:00, 115.62it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="670a029b-c36f-4841-976a-e774a4b8145a" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("670a029b-c36f-4841-976a-e774a4b8145a")) {                    Plotly.newPlot(                        "670a029b-c36f-4841-976a-e774a4b8145a",                        [{"customdata":[["</br>id: 150</br>prediction: 0.454</br>age: 29.0</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 29.48</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 29.96</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 30.44</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 30.92</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 31.4</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 31.88</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 0.0</br>slp_1: 0.0</br>slp_2: 1.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.4969589114189148</br>"],["</br>id: 150</br>prediction: 0.454</br>age: 32.36</br></br>sex: 1.0</br>trtbps: 160.0</br>chol: 228.0</br>fbs: 0.0</br>thalachh: 138.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 1.0</br>re ...
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:00<00:00, 128.55it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="512638cb-ee49-4ac4-8a28-bdbf8af5e1ae" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("512638cb-ee49-4ac4-8a28-bdbf8af5e1ae")) {                    Plotly.newPlot(                        "512638cb-ee49-4ac4-8a28-bdbf8af5e1ae",                        [{"customdata":[["</br>id: 225</br>prediction: 0.037</br>age: 29.0</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 29.48</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 29.96</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 30.44</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 30.92</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 31.4</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 31.88</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0</br>restecg_1: 1.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 0.0</br>thall_2: 0.0</br>thall_3: 1.0</br>_original_yhat_: 0.09892398864030838</br>"],["</br>id: 225</br>prediction: 0.037</br>age: 32.36</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 174.0</br>fbs: 0.0</br>thalachh: 125.0</br>exng: 1.0</br>oldpeak: 2.6</br>caa: 0.0</br>cp_0: 1.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 0.0</br>restecg_0: 0.0 ...

# %%
cp_many = explainer.predict_profile(observations)
cp_many.plot(variables=['age'])
# Out:
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:00<00:00, 149.38it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="09ab165e-4b8b-40ef-98f1-cb63b0301eee" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09ab165e-4b8b-40ef-98f1-cb63b0301eee")) {                    Plotly.newPlot(                        "09ab165e-4b8b-40ef-98f1-cb63b0301eee",                        [{"customdata":[["</br>id: 0</br>prediction: 0.81</br>age: 29.0</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 29.48</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 29.96</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 30.44</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 30.92</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 31.4</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 31.88</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0</br>slp_0: 1.0</br>slp_1: 0.0</br>slp_2: 0.0</br>thall_0: 0.0</br>thall_1: 1.0</br>thall_2: 0.0</br>thall_3: 0.0</br>_original_yhat_: 0.656713604927063</br>"],["</br>id: 0</br>prediction: 0.81</br>age: 32.36</br></br>sex: 1.0</br>trtbps: 145.0</br>chol: 233.0</br>fbs: 1.0</br>thalachh: 150.0</br>exng: 0.0</br>oldpeak: 2.3</br>caa: 0.0</br>cp_0: 0.0</br>cp_1: 0.0</br>cp_2: 0.0</br>cp_3: 1.0</br>restecg_0: 1.0</br>restecg_1: 0.0</br>restecg_2: 0.0 ...

# %% [markdown]
# ## PDP

# %%
pdp = explainer.model_profile()
pdp.plot(variables=['age'])
# Out:
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:01<00:00, 11.69it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0b9602aa-3220-458b-9309-e9e709d62d60" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b9602aa-3220-458b-9309-e9e709d62d60")) {                    Plotly.newPlot(                        "0b9602aa-3220-458b-9309-e9e709d62d60",                        [{"customdata":[[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"],[0.541362464427948,"GBM","age"]],"hovertemplate":"<b>%{hovertext}</b><br><br>prediction=%{y:.3f}<br>mean_prediction=%{customdata[0]:.3f}<extra></extra>","hovertext":["GBM","GBM","GBM","GBM","GBM","GBM","GBM","GBM","GBM","GBM","GBM","GBM", ...

# %% [markdown]
# ## Random Forest (another model)

# %%
RF_model = RandomForestClassifier(class_weight='balanced', random_state=SEED).fit(X, y)
explainer_rf = dx.Explainer(RF_model, X, y, predict_function=pf_xgboost_classifier_default, label="LR")
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 303 rows 23 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 303 values
#   -> model_class       : sklearn.ensemble._forest.RandomForestClassifier (default)
#   -> label             : LR
#   -> predict function  : <function <lambda> at 0x7f95549dadd0> will be used
#   -> predict function  : Accepts pandas.DataFrame and numpy.ndarray.
#   -> predicted values  : min = 0.0, mean = 0.547, max = 1.0
#   -> model type        : classification will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -0.44, mean = -0.00241, max = 0.34
#   -> model_info        : package sklearn
#
# A new explainer has been created!
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning:
#
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names

# %%
explainer_rf.model_performance()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f1</th>
#       <th>accuracy</th>
#       <th>auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LR</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
explainer_rf.predict(observations)
# Out:
# array([0.85, 0.97, 0.74, 0.04])

# %%
pdp_rf = explainer_rf.model_profile()
pdp_rf.plot(variables=['age'])
# Out:
# Calculating ceteris paribus: 100%|██████████| 23/23 [00:06<00:00,  3.44it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2b3b5128-1c98-453f-9811-3f756ed64101" class="plotly-graph-div" style="height:489px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b3b5128-1c98-453f-9811-3f756ed64101")) {                    Plotly.newPlot(                        "2b3b5128-1c98-453f-9811-3f756ed64101",                        [{"customdata":[[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"],[0.5490666666666667,"LR","age"]],"hovertemplate":"<b>%{hovertext}</b><br><br>prediction=%{y:.3f}<br>mean_prediction=%{customdata[0]:.3f}<extra></extra>","hovertext":["LR","LR","LR","LR","LR","LR","LR","LR","LR","LR","LR","LR","LR","LR","L ...
